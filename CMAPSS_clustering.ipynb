# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv(r'C:\Users\Jiao Yuehan\Desktop\IT5006\Project_IT5006\pres\CMAPSSData\train_FD001.txt', delim_whitespace=True, header=None)
df1
# Out:
# C:\Users\Jiao Yuehan\AppData\Local\Temp\ipykernel_12148\580570263.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df1=pd.read_csv(r'C:\Users\Jiao Yuehan\Desktop\IT5006\Project_IT5006\pres\CMAPSSData\train_FD001.txt', delim_whitespace=True, header=None)
#         0    1       2       3      4       5       6        7        8   \
# 0        1    1 -0.0007 -0.0004  100.0  518.67  641.82  1589.70  1400.60
# 1        1    2  0.0019 -0.0003  100.0  518.67  642.15  1591.82  1403.14
# 2        1    3 -0.0043  0.0003  100.0  518.67  642.35  1587.99  1404.20
# 3        1    4  0.0007  0.0000  100.0  518.67  642.35  1582.79  1401.87
# 4        1    5 -0.0019 -0.0002  100.0  518.67  642.37  1582.85  1406.22
# ...    ...  ...     ...     ...    ...     ...     ...      ...      ...
# 20626  100  196 -0.0004 -0.0003  100.0  518.67  643.49  1597.98  1428.63
# ...

# %%
df2=pd.read_csv(r'C:\Users\Jiao Yuehan\Desktop\IT5006\Project_IT5006\pres\CMAPSSData\train_FD002.txt', delim_whitespace=True, header=None)
df2
# Out:
# C:\Users\Jiao Yuehan\AppData\Local\Temp\ipykernel_28248\3447041714.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df2=pd.read_csv(r'C:\Users\Jiao Yuehan\Desktop\IT5006\Project_IT5006\pres\CMAPSSData\train_FD002.txt', delim_whitespace=True, header=None)
#         0    1        2       3      4       5       6        7        8   \
# 0        1    1  34.9983  0.8400  100.0  449.44  555.32  1358.61  1137.23
# 1        1    2  41.9982  0.8408  100.0  445.00  549.90  1353.22  1125.78
# 2        1    3  24.9988  0.6218   60.0  462.54  537.31  1256.76  1047.45
# 3        1    4  42.0077  0.8416  100.0  445.00  549.51  1354.03  1126.38
# 4        1    5  25.0005  0.6203   60.0  462.54  537.07  1257.71  1047.93
# ...    ...  ...      ...     ...    ...     ...     ...      ...      ...
# 53754  260  312  20.0037  0.7000  100.0  491.19  608.79  1495.60  1269.51
# ...

# %%
df3=pd.read_csv(r'C:\Users\Jiao Yuehan\Desktop\IT5006\Project_IT5006\pres\CMAPSSData\train_FD003.txt', delim_whitespace=True, header=None)
df3
# Out:
# C:\Users\Jiao Yuehan\AppData\Local\Temp\ipykernel_12148\325722040.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df3=pd.read_csv(r'C:\Users\Jiao Yuehan\Desktop\IT5006\Project_IT5006\pres\CMAPSSData\train_FD003.txt', delim_whitespace=True, header=None)
#         0    1       2       3      4       5       6        7        8   \
# 0        1    1 -0.0005  0.0004  100.0  518.67  642.36  1583.23  1396.84
# 1        1    2  0.0008 -0.0003  100.0  518.67  642.50  1584.69  1396.89
# 2        1    3 -0.0014 -0.0002  100.0  518.67  642.18  1582.35  1405.61
# 3        1    4 -0.0020  0.0001  100.0  518.67  642.92  1585.61  1392.27
# 4        1    5  0.0016  0.0000  100.0  518.67  641.68  1588.63  1397.65
# ...    ...  ...     ...     ...    ...     ...     ...      ...      ...
# 24715  100  148 -0.0016 -0.0003  100.0  518.67  643.78  1596.01  1424.11
# ...

# %%
df4=pd.read_csv(r'C:\Users\Jiao Yuehan\Desktop\IT5006\Project_IT5006\pres\CMAPSSData\train_FD004.txt', delim_whitespace=True, header=None)
df4
# Out:
# C:\Users\Jiao Yuehan\AppData\Local\Temp\ipykernel_12148\2130140162.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df4=pd.read_csv(r'C:\Users\Jiao Yuehan\Desktop\IT5006\Project_IT5006\pres\CMAPSSData\train_FD004.txt', delim_whitespace=True, header=None)
#         0    1        2       3      4       5       6        7        8   \
# 0        1    1  42.0049  0.8400  100.0  445.00  549.68  1343.43  1112.93
# 1        1    2  20.0020  0.7002  100.0  491.19  606.07  1477.61  1237.50
# 2        1    3  42.0038  0.8409  100.0  445.00  548.95  1343.12  1117.05
# 3        1    4  42.0000  0.8400  100.0  445.00  548.70  1341.24  1118.03
# 4        1    5  25.0063  0.6207   60.0  462.54  536.10  1255.23  1033.59
# ...    ...  ...      ...     ...    ...     ...     ...      ...      ...
# 61244  249  251   9.9998  0.2500  100.0  489.05  605.33  1516.36  1315.28
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
op1=df2.iloc[:,2]
op2=df2.iloc[:,3]
op3=df2.iloc[:,4]
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(op1, op2, op3)
ax.set_xlabel('operational_setting_1')
ax.set_ylabel('operational_setting_2')
ax.set_zlabel('operational_setting_3')
ax.tick_params(axis='x', pad=8)
ax.tick_params(axis='y', pad=8)
ax.tick_params(axis='z', pad=8)
plt.tight_layout()
plt.show()

# %%
df2[2]
# Out:
# 0        34.9983
# 1        41.9982
# 2        24.9988
# 3        42.0077
# 4        25.0005
#           ...
# 53754    20.0037
# 53755    10.0022
# 53756    25.0041
# 53757    25.0033
# 53758    35.0036
# Name: 2, Length: 53759, dtype: float64

# %%
plt.scatter(df2.index, df2[2],marker='o')

# %%
plt.scatter(df2.index, df2[3], marker='x', label='Column 3', color='g')

# %%
plt.scatter(df2.index, df2[4], marker='s', label='Column 4', color='r')

# %%
from mpl_toolkits.mplot3d import Axes3D
op1=df1.iloc[:,2]
op2=df1.iloc[:,3]
op3=df1.iloc[:,4]
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(op1, op2, op3)
ax.set_xlabel('operational_setting_1')
ax.set_ylabel('operational_setting_2')
ax.set_zlabel('operational_setting_3')
ax.tick_params(axis='x', pad=8)
ax.tick_params(axis='y', pad=8)
ax.tick_params(axis='z', pad=8)
plt.tight_layout()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
op1=df4.iloc[:,2]
op2=df4.iloc[:,3]
op3=df4.iloc[:,4]
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(op1, op2, op3)
ax.set_xlabel('operational_setting_1')
ax.set_ylabel('operational_setting_2')
ax.set_zlabel('operational_setting_3')
ax.tick_params(axis='x', pad=8)
ax.tick_params(axis='y', pad=8)
ax.tick_params(axis='z', pad=8)
plt.tight_layout()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
op1=df3.iloc[:,2]
op2=df3.iloc[:,3]
op3=df3.iloc[:,4]
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(op1, op2, op3)
ax.set_xlabel('operational_setting_1')
ax.set_ylabel('operational_setting_2')
ax.set_zlabel('operational_setting_3')
ax.tick_params(axis='x', pad=8)
ax.tick_params(axis='y', pad=8)
ax.tick_params(axis='z', pad=8)
plt.tight_layout()
plt.show()
